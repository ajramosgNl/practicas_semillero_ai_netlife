# %% [markdown]
# # 🧪 Practica 9

# %% [markdown]
# # Prompt Engineering Básico

# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# Eres un ingeniero junior en sistemas implementando logging estructurado en una app de e-commerce con 50 microservicios en Kubernetes, usando ELK stack (Elasticsearch, Logstash, Kibana). Asume conocimiento intermedio en logging con Fluentd y métricas en Prometheus. Debes proporciona 3 estrategias prácticas para optimizar el volumen de logs y mejorar la detección de anomalías, enfocándote en filtrado y agregación.
# Necesitas que el formato de respuesta, este de la siguiente manera: Tabla Markdown con columnas: Estrategia | Descripción (máx 1 párrafo) | Métricas de impacto | Configuración recomendada en tools.Por otra parte, tienes las siguientes restricciones: Enfócate en soluciones implementables en K8s/ELK sin migraciones; lenguaje técnico accesible; excluye costos de storage; cada estrategia con impacto medible (e.g., % reducción logs); no incluyas ejemplos de código extensos; prioriza logs de alto volumen como auth y payments.

# %%
import os
from openai import OpenAI

client = OpenAI(
    api_key="AIzaSyDjSbFVf25PmVRHiuqhF7Bd8mI5VaVaOI0",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)


prompt = """

"""

response = client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)


print(response.choices[0].message)

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# Eres un ingeniero junior en sistemas debuggeando un pipeline de CI/CD en Jenkins que falla intermitentemente durante builds de una app Java con microservicios; el pipeline incluye stages de test, build Docker y deploy a Kubernetes. Asume conocimiento intermedio en Jenkins, Docker y K8s.
# Diagnostica posibles causas del fallo intermitente y proporciona 4 pasos de troubleshooting prácticos para resolverlo, enfocándote en bottlenecks comunes como recursos, networking o configuración.Por otra parte, el formato de respuesta debe ser de la siguiente manera:
# Lista numerada 1-4 con cada paso, incluyendo: Descripción breve | Comando o acción específica | Verificación esperada.Así mismo, tienes que tener en cuenta las siguientes restricciones: Limita a soluciones prácticas sin cambios arquitectónicos mayores; usa lenguaje técnico accesible; excluye problemas de código fuente; cada paso máximo 75 palabras; prioriza diagnósticos en stages de build y deploy; asegura pasos secuenciales para un junior.

# %%
import os
from openai import OpenAI

client = OpenAI(
    api_key="AIzaSyDjSbFVf25PmVRHiuqhF7Bd8mI5VaVaOI0",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)


prompt = """

"""

response = client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)


print(response.choices[0].message)
